# %%
import pandas as pd
import numpy as np

# %%
d = pd.read_csv(r"C:\Users\user\Downloads\imdb_anime.csv")

# %%
d
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 3                                  Attack on Titan
# 4                                   Jujutsu Kaisen
# ...                                            ...
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
# 45714                                    One Piece
# 45715                                Marmalade Boy
# 45716                              Cinderella Nine
#
#                               Genre User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure         8.9         187,689  24 min
# 1      Animation, Action, Adventure         7.4          28,895  99 min
# 2      Animation, Adventure, Comedy         7.1         189,108  92 min
# ...

# %%
d.describe()
# Out:
#            Title                         Genre User Rating Number of Votes  \
# count      45717                         45717       25009           25009
# unique      9851                           201          87            3033
# top     Doraemon  Animation, Action, Adventure         7.6               7
# freq        2758                         13568        1270             567
#
#        Runtime      Year                                            Summary  \
# count    32549     45591                                              23547
# unique     196       740                                              22588
# top     24 min  (1969– )  A young teen who surfs the skies with his ref ...
# freq      9636      2399                                                 25
#
#                                                     Stars Certificate  \
# count                                               13676       28694
# ...

# %% [markdown]
# ## 1)

# %%
d["Title"].unique().shape
# Out:
# (9851,)

# %% [markdown]
# ## 11)

# %%
ce = d.groupby(["Certificate"])

# %%
ce

# %%
ce.ngroups
# Out:
# 34

# %%
ce.get_group("PG")
# Out:
#                                              Title  \
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 7                     Puss in Boots: The Last Wish
# 11                                        Coraline
# 17                                          Sing 2
# ...                                            ...
# 41231                         You're Under Arrest!
# 41232                         You're Under Arrest!
# 41233                         You're Under Arrest!
# 41234                         You're Under Arrest!
# 41235                         You're Under Arrest!
#
#                               Genre User Rating Number of Votes  Runtime  \
# 1      Animation, Action, Adventure         7.4          28,895   99 min
# 2      Animation, Adventure, Comedy         7.1         189,108   92 min
# 7      Animation, Adventure, Comedy         7.8         153,495  102 min
# ...

# %% [markdown]
# ## 2)

# %%
d.sort_values(by = "User Rating",ascending = False).head()
# Out:
#                  Title                         Genre  User Rating  \
# 840              Title                         Genre  User Rating
# 45689  Attack on Titan  Animation, Action, Adventure          9.9
# 13656      Idaten Jump  Animation, Adventure, Comedy          9.9
# 34677  Hunter x Hunter  Animation, Action, Adventure          9.9
# 22753  Attack on Titan  Animation, Action, Adventure          9.9
#
#        Number of Votes  Runtime         Year  \
# 840    Number of Votes  Runtime         Year
# 45689          109,163   24 min  (2013–2023)
# 13656               11   20 min  (2005–2006)
# 34677            9,012   23 min  (2011–2014)
# 22753           86,907   24 min  (2013–2023)
#
#                                                  Summary  \
# 840                                              Summary
# 45689  As Erwin's heroic charge buys Levi time to con...
# 13656                                                NaN
# 34677  Gon goes beyond his body limits to achieve mon...
# ...

# %% [markdown]
# ## 4)

# %%
d['Runtime'] = d['Runtime'].str.extract('(\d+)').astype(float)

# %%
highest=d.loc[d['Runtime'].idxmax()]
lowest=d.loc[d['Runtime'].idxmin()]

# %%
print("Anime with the highest runtime:")
print(highest[['Title', 'Runtime']])

print("\nAnime with the lowest runtime:")
print(lowest[['Title', 'Runtime']])
# Out:
# Anime with the highest runtime:
# Title      Figure 17
# Runtime        780.0
# Name: 5522, dtype: object
#
# Anime with the lowest runtime:
# Title      Golgo 13
# Runtime         1.0
# Name: 2585, dtype: object

# %% [markdown]
# ## 5)

# %%
d['Runtime'] = d['Runtime'].str.extract('(\d+)').astype(float)

# %%
movie1 = d[d["Title"]=="One Piece"]["Runtime"].values[0]
movie2 = d[d["Title"]=="The Super Mario Bros. Movie"]["Runtime"].values[0]
run_time = abs(movie1 - movie2)
print(run_time)
# Out:
# 68.0

# %% [markdown]
# ## 6)

# %%
d['Year'] = d['Year'].str.extract('(\d+)').astype(float)

# %%
d[d["Year"]==d["Year"].min()]
# Out:
#                    Title             Genre User Rating Number of Votes  \
# 4954  Matsumoto Fragment  Animation, Short         5.4             352
#
#       Runtime    Year                                            Summary  \
# 4954      1.0  1907.0  A boy writes on a board, then tips his hat to ...
#
#      Stars Certificate Metascore Gross Episode Episode Title
# 4954   NaN         NaN       NaN   352       0           NaN

# %% [markdown]
# ## 7)

# %%
d[d["Year"]==2023]

# %%
# Out:
#                                              Title  \
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 13                           The Boy and the Heron
# 18                Zom 100: Bucket List of the Dead
# 21                    Ruby Gillman, Teenage Kraken
# ...                                            ...
# 32965                    Beyblade Burst QuadStrike
# 32966                    Beyblade Burst QuadStrike
# 32967                    Beyblade Burst QuadStrike
# 32968                    Beyblade Burst QuadStrike
# 32969                    Beyblade Burst QuadStrike
#
#                               Genre User Rating Number of Votes  Runtime  \
# 1      Animation, Action, Adventure         7.4          28,895     99.0
# 2      Animation, Adventure, Comedy         7.1         189,108     92.0
# 13      Animation, Adventure, Drama         7.6             829    124.0
# ...

# %% [markdown]
# ## 8)

# %%
d['User Rating'] = pd.to_numeric(d['User Rating'])
ac = d[d["Genre"].str.contains("Action",na=False)]

# %%
ac["User Rating"].mean()
# Out:
# 7.334487401423351

# %% [markdown]
# ## 9)

# %%
d.dropna(subset=['Gross'], inplace=True)
d["Gross"]=d["Gross"].str.replace(","," ",regex=True)
d[d["Gross"]==d["Gross"].min()]
# Out:
#                                  Title                         Genre  \
# 4596   The Everyday Tales of a Cat God    Animation, Comedy, Fantasy
# 4743                    SSSS.Dynazenon  Animation, Action, Adventure
# 4949                       Petit Sekai      Animation, Short, Comedy
# 5275           Yo-kai Watch Shadowside                     Animation
# 5300                      Eternal Boys              Animation, Music
# ...                                ...                           ...
# 45200                        Last Hope  Animation, Action, Adventure
# 45202                        Last Hope  Animation, Action, Adventure
# 45203                        Last Hope  Animation, Action, Adventure
# 45204                        Last Hope  Animation, Action, Adventure
# 45244                         3x3 Eyes    Animation, Fantasy, Horror
#
#       User Rating Number of Votes Runtime         Year  \
# 4596          7.1              10     NaN     (2011– )
# ...

# %% [markdown]
# ## 10)

# %%
d['Gross'] = d['Gross'].str.replace(',', '', regex=True)  # Remove commas
d['Gross'] = pd.to_numeric(d['Gross'],errors="coerce")

highest_gross = d[d['Gross'] == d['Gross'].max()]

print("Anime with the highest gross price:")
print(highest_gross[['Title', 'Gross']])
# Out:
# Anime with the highest gross price:
#       Title      Gross
# 47   WALL·E  1162284.0
# 888  WALL·E  1162284.0

# %% [markdown]
# ## 3)

# %%
d["User Rating"] = pd.to_numeric(d["User Rating"])

d[(d["User Rating"] >= 7.0) & (d["User Rating"] <= 9.0)]
# Out:
#                                              Title  \
# 0                                        One Piece
# 1      Teenage Mutant Ninja Turtles: Mutant Mayhem
# 2                      The Super Mario Bros. Movie
# 4                                   Jujutsu Kaisen
# 6                   Demon Slayer: Kimetsu no Yaiba
# ...                                            ...
# 45709               Demon Slayer: Kimetsu no Yaiba
# 45710               Demon Slayer: Kimetsu no Yaiba
# 45711               Demon Slayer: Kimetsu no Yaiba
# 45712               Demon Slayer: Kimetsu no Yaiba
# 45713               Demon Slayer: Kimetsu no Yaiba
#
#                               Genre  User Rating Number of Votes Runtime  \
# 0      Animation, Action, Adventure          8.9         187,689  24 min
# 1      Animation, Action, Adventure          7.4          28,895  99 min
# 2      Animation, Adventure, Comedy          7.1         189,108  92 min
# ...
